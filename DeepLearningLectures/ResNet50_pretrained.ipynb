# %%
import keras
from keras.applications.resnet50 import ResNet50, preprocess_input, decode_predictions
import numpy as np

# %%
model = ResNet50(weights='imagenet')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels.h5
# 102967424/102967424 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
img_pth = '/content/beetle.png'
img = keras.utils.load_img(img_pth, target_size=(224, 224))

x = keras.utils.img_to_array(img)
x = preprocess_input(x)
x = np.expand_dims(x, axis=0)

# %%
# predict using model
preds = model.predict(x)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step

# %%
label = decode_predictions(preds)
print(label)
# Out:
# [[('n02172182', 'dung_beetle', 0.52175796), ('n02174001', 'rhinoceros_beetle', 0.27597246), ('n02169497', 'leaf_beetle', 0.09795448), ('n02177972', 'weevil', 0.05352838), ('n02167151', 'ground_beetle', 0.015100346)]]
